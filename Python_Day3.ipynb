# %% [markdown]
# # print function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Machine Learning")

# %%
print("Machine Learning" + " Projects")

# %%
print(8)

# %%
print(8+3)

# %%
a = "My friend"
b = "Mangoes"
print("{0} love {1}".format(a,b))

# %%
name = 'Omer'
age = 22
print(f"Hello, My name is {name} and I'm {age} years old.")

# %% [markdown]
# # Basic Syntax Rules In Python

# %%
## Case sensitivity- Python is case sensitive

name="Ahmad"
Name="ahmad"

print(name)
print(Name)

# %% [markdown]
# **Indentation** in Python is used to define the structure and hierarchy of the code. Unlike many other programming languages that use braces {} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be indented at the same level.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Indentation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.

age=32
if age>30:
    print(age)

print(age)

# %%
## this is single line comment
'''
this is a exmaple of multiline comments
'''
'''
Welcome to the
python course


'''

# %% [markdown]
# # Data Type & Variables

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Declaring And Assigning Variables

age=20
height=161.3
name="Ali"
is_student=True

## printing the variables

print("age :",age)
print("Height:",height)
print("Name:",name)

# %%
## Naming Conventions
## Variable names should be descriptive
## They must start with a letter or an '_' and contains letter,numbers and underscores
## variables names case sensitive

#valid variable names

first_name="Ahamd"
last_name="Khald"

# %%
# Invalid variable names
#2age=30
#first-name="Omer"
##@name="Omer"

# %%
## case sensitivity
name="Ahmad"
Name="Omer"

print(name)

# %%
## Understnading Variable types
## Python is dynamically typed,type of a variable is determined at runtime
age=20 #int
height=170.1 #float
name="Ahmad" #str
is_student=True #bool

print(type(name))

# %%
type(height)

# %%
age=25
print(type(age))

# %%
# Type conversion
age_str=str(age)
print(age_str)
print(type(age_str))

# %%
age='25'
print(type(int(age)))

# %%
name="Ahmad"
int(name)

# %%
hero1 , hero2 , hero3 = "Iron Man" , "Captain America" , "Bat Man"
print(hero1)
print(hero2)
print(hero3)

# %%
x = y = z = 23
print(x)
print(y)
print(z)

# %% [markdown]
# # input Function

# %%
number_1 = int(input("Enter the first number : "))
number_2 = int(input("Enter the second number : "))

sum = number_1 + number_2
print(sum)

# %% [markdown]
# # Operators

# %% [markdown]
# 1. Arithmetic Operators
#    - Addition
#    - Subtraction
#    - Multiplication
#    - Division
#    - Floor Division
#    - Modulus
#    - Exponentiation
# 2. Comparison Operators
#    - Equal to
#    - Not equal to
#    - Greater than
#    - Less than
#    - Greater than or equal to
#    - Less than or equal to
# 3. Logical Operators
#    - AND
#    - OR
#    - NOT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Arithmethic Operation

# %%
## Arithmethic Operation

a=10
b = 5

add_result=a+b  #addiiton
sub_result=a-b  #substraction
mult_result=a*b #multiplication
div_result=a/b  #division
floor_div_result=a//b ## floor division
modulus_result=a%b #modulus operation

exponent_result=a**b ## Exponentiation


print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_result)

# %%
10/5

# %%
21/5

# %%
21//5

# %% [markdown]
# ### Comparison Operators

# %%
## Comparison Operators
## == Equal to
a=10
b=10

a==b

# %%
str1="Ali"
str2="Ali"

str1==str2

# %%
## Not Equal to !=
str1!=str2

# %%
str3="ali"
str4="Ali"

str3!=str4

# %%
# greater than >

num1=45
num2=55

num1>num2

# %%
## less than <

print(num1<num2)

# %%
#greater than or equal to
number1=45
number2=45

print(number1>=number2)

# %%
#less than or equal to
number1=44
number2=45

print(number1<=number2)

# %% [markdown]
# ### Logical Operators

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## And ,Not,OR
X=True
Y=True

result =X and Y
print(result)

# %%
X=False
Y=True

result =X and Y
print(result)

# %%
## OR
X=False
Y=False

result =X or Y
print(result)

# %%
# Not operator
X=False
not X

# %%
## Simple Calculator

# Simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# Performing arithmetic operations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2

# Displaying results
print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", floor_division)
print("Modulus:", modulus)
print("Exponentiation:", exponentiation)

# %% [markdown]
# # List_Tuple_Set_Dictionary

# %% [markdown]
#  **A good reference**: https://github.com/krishnaik06/Complete-Python-Bootcamp/tree/main/3-Data%20Structures

# %% [markdown]
# ## List

# %%
# list should be included in the square brackets
my_list = [1,2,3,4,5]
print(my_list)
type(my_list)

# %%
# lists can have multiple data types
my_list = [2, 3, 1.8, 'English', True]
print(my_list)

# %%
# add elements to a list
my_list = [2, 3, 1.8, 'English', True]
my_list.append(6)
print(my_list)

# %%
# print elements of a list using their index
print(my_list[0])
print(my_list[2])

# %%
# lists allow duplicate values
list_1 = [1,2,3,4,5,12,2,3]
print(list_1)

# %%
print(len(list_1))

# %%
# initiating an empty list
list_2 = []
print(list_2)

# %%
list_2.append(5)
print(list_2)

# %%
# delete an item in a list
list_2 = [2, 3, 1.8, 'English', True, 6]
print(list_2)

del list_2[2]
print(list_2)

# %% [markdown]
# ### 📌 Task:
#
# Create a list with three student names.
# Use print to display each student's name on a separate line.

# %%
students = ["Ali", "Sara", "Faisal"]

print(students[0])
print(students[1])
print(students[2])
# Out:
# Ali
# Sara
# Faisal

# %% [markdown]
# ### 📌 Task:
# Create a list with three products.
# ```
# products = ["Laptop", "Mouse", "Keyboard"]
# ```
# Replace the second product with another.
#
# Print the updated list.

# %%
products = ["Laptop", "Mouse", "Keyboard"]

products[1] = "Monitor"

print("Updated List:", products)
# Out:
# Updated List: ['Laptop', 'Monitor', 'Keyboard']

# %% [markdown]
# ## Tuple

# %%
tuple_1 = (2,3,4,5)
print(tuple_1)
type(tuple_1)

# %%
# tuple allows multiple data types
my_tuple = (1,2,3.5, 'Machine Learning', False)
print(my_tuple)

# %%
print(my_tuple[0])
print(my_tuple[1])

# %% [markdown]
# Tuples are immutable --> Unchangeable

# %%
my_tuple.append(6)

# %%
my_tuple[0]=100

# %%
print(len(my_tuple))

# %% [markdown]
# ## Set

# %%
# set --> Curly brackets
my_set = {1,2,3,4,5}
print(my_set)
type(my_set)

# %%
print(my_set[0])

# %%
# set does not allow duplicate values
set_3 = {1,2,3,4,5,1,2,3}
print(set_3)

# %%
set_3.add(9)

# %%
set_3

# %%
set_3.remove(4)

# %%
set_3

# %% [markdown]
# ## Dictionary

# %% [markdown]
# Key-Value Pair

# %%
my_dictionary = {'name':'David','age':30,'country':'US'}
print(my_dictionary)
type(my_dictionary)

# %%
print(my_dictionary['name'])
print(my_dictionary['age'])
print(my_dictionary['country'])

# %%
# dictionary does not allow duplicate Keys
dictionary_2 = {'name':'David','age':30,'country':'US','name':'David','age':30,'country':'UK'}
print(dictionary_2)

# %% [markdown]
# ###📌 Task:
#
# Create a dictionary with employee name, salary, and age.
#
# Print each value using print.

# %%
employee = {
    "name": "Omar",
    "salary": 5000,
    "age": 30
}

print("الاسم:", employee["name"])
print("الراتب:", employee["salary"])
print("العمر:", employee["age"])
# Out:
# الاسم: Omar
# الراتب: 5000
# العمر: 30

# %% [markdown]
# ###📌 Task:
# Change the name in the last Dictionary to be Amjad
#
# Print each value using print.

# %%
employee["name"] = "Amjad"


print("الاسم:", employee["name"])
print("الراتب:", employee["salary"])
print("العمر:", employee["age"])
# Out:
# الاسم: Amjad
# الراتب: 5000
# العمر: 30

# %% [markdown]
# # Conditional Statements (if, elif, else)

# %%
## if statement
age=20

if age>=18:
    print("You are allowed to drive a car")

# %%
## else
## The else statement executes a block of code if the condition in the if statement is False.

age=16

if age>=18:
    print("You are allowed to drive a car")
else:
    print("You cant drive a car")

# %%
## elif
## The elif statement allows you to check multiple conditions. It stands for "else if"

age=17

if age<13:
    print("You are a child")
elif age<18:
    print("You are a teenager")
else:
    print("You are an adult")

# %%
num=int(input("Enter the number"))

if num>0:
  print("positive")
elif num<0:
  print("negative")
else:
  print("number is Zero")

# %% [markdown]
# ###### Challenge: Write a program that accepts a number from the user and determines whether the number is odd or even.

# %%
## Nested Condiitonal Statements

# You can place one or more if, elif, or else statements inside another if, elif, or else statement to create nested conditional statements.

## number even ,odd,negative

num=int(input("Enter the number"))

if num>0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")

else:
    print("The number is zero or negative")

# %% [markdown]
# ###### Challenge:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
per = int(input("Enter Marks:"))
if per > 90:
  print("A")
elif per > 80 and per <= 90:
  print("B")
elif per >= 60 and per <=80:
  print("C")
elif per<60:
  print("D")
# Out:
# Enter Marks:50
# D

# %% [markdown]
# ###### Challenge:
# User Login System
# A simple user login system that checks the username and password.

# %%
# User login system

# Predefined username and password
stored_username = "admin"
stored_password = "password123"

# Take user input
username = input("Enter username: ")
password = input("Enter password: ")

# Check login credentials
if username == stored_username:
    if password == stored_password:
        print("Login successful!")
    else:
        print("Incorrect password.")
else:
    print("Username not found.")

# %% [markdown]
# ###### Challenge:
# Simple Calculator program

# %%
# Take user input
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")

# Perform the requested operation
if operation == '+':
    result = num1 + num2
elif operation == '-':
    result = num1 - num2
elif operation == '*':
    result = num1 * num2
elif operation == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
else:
    result = "Invalid operation."

print("Result:", result)
